# %%
import pandas as pd
import numpy as np
import os
import time
from collections import namedtuple
pd.set_option("display.max_rows",100)
# %matplotlib inline

# %%
train_paths = {"mawiitrain":"dataset/preprocessed_train_data5.pkl"}
test_paths = {"mawiitest":"dataset/preprocessed_test4_data.pkl"}

class preprocess:
    
    def get_data(paths):
        
        for key, value in paths.items():
            sample_data = pd.read_pickle(value)
            x = sample_data.iloc[:,:-2]
            y = sample_data.iloc[:,-2:]
            yield key, x.values, y.values

# %%
import tensorflow as tf
from tensorflow.contrib.legacy_seq2seq.python.ops.seq2seq import basic_rnn_seq2seq
from tensorflow.contrib.rnn import RNNCell, LSTMCell, MultiRNNCell
from sklearn import model_selection as ms
from sklearn import metrics as me
# Out:
# c:\users\anusha\appdata\local\programs\python\python36\lib\site-packages\h5py\__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %%
class network(object):
    
    input_dim = 4
    classes = 2
    hidden_encoder_dim = 4
    hidden_layers = 1
    latent_dim = 5

    hidden_decoder_dim = 4
    lam = 0.01
    
    def __init__(self, classes, hidden_layers, num_of_features):
        self.classes = classes
        self.hidden_layers = hidden_layers
        self.latent_dim = num_of_features
            
    def build_layers(self):
        tf.reset_default_graph()
        #learning_rate = tf.Variable(initial_value=0.001)

        input_dim = self.input_dim
        classes = self.classes
        hidden_encoder_dim = self.hidden_encoder_dim
        hidden_layers = self.hidden_layers
        latent_dim = self.latent_dim
        hidden_decoder_dim = self.hidden_decoder_dim
        lam = self.lam
        
        with tf.variable_scope("Input"):
            self.x_input = tf.placeholder("float", shape=[None, 1, input_dim])
            self.y_input_ = tf.placeholder("float", shape=[None, 1, classes])
            self.keep_prob = tf.placeholder("float")
            self.lr = tf.placeholder("float")
            self.x_list = tf.unstack(self.x_input, axis= 1)
            self.y_list_ = tf.unstack(self.y_input_, axis = 1)
            self.y_ = self.y_list_[0]
            
            #GO = tf.fill((tf.shape(self.x)[0], 1), 0.5)
            
            #y_with_GO = tf.stack([self.y_, GO])
            
        with tf.variable_scope("lstm"):
            multi_cell = MultiRNNCell([LSTMCell(input_dim) for i in range(hidden_layers)] )
            
            self.y, states = basic_rnn_seq2seq(self.x_list, self.y_list_, multi_cell)
            #self.y = tf.slice(self.y, [0, 0], [-1,2])
            
            #self.out = tf.squeeze(self.y)
            
            #self.y = tf.layers.dense(self.y[0], classes, activation = None)
            
            self.y = tf.slice(self.y[0], [0, 0], [-1,2])
            
        with tf.variable_scope("Loss"):
            
            self.regularized_loss = tf.losses.mean_squared_error(self.y_, self.y)
            correct_prediction = tf.equal(tf.argmax(self.y_, 1), tf.argmax(self.y, 1))
            self.tf_accuracy = tf.reduce_mean(tf.cast(correct_prediction, tf.float32), name = "Accuracy")

        with tf.variable_scope("Optimizer"):
            learning_rate=self.lr
            optimizer = tf.train.AdamOptimizer(learning_rate)
            gradients, variables = zip(*optimizer.compute_gradients(self.regularized_loss))
            gradients = [
                None if gradient is None else tf.clip_by_value(gradient, -1, 1)
                for gradient in gradients]
            self.train_op = optimizer.apply_gradients(zip(gradients, variables))
            #self.train_op = optimizer.minimize(self.regularized_loss)
            
        # add op for merging summary
        #self.summary_op = tf.summary.merge_all()
        self.pred = tf.argmax(self.y, axis = 1)
        self.actual = tf.argmax(self.y_, axis = 1)

        # add Saver ops
        self.saver = tf.train.Saver()

# %%
import collections

class Train:    
    
    result = namedtuple("score", ['key', 'no_of_features','hidden_layers','train_score', 'test_score', 'quality_score', 'time_taken'])

    predictions = {}

    results = []
    best_acc = 0
    best_acc_global = 0

    def train(epochs, net, h,f, lrs):
        batch_iterations = 1000
        train_loss = None
        Train.best_acc = 0
        os.makedirs("dataset/tf_lstm_nsl_kdd-orig/hidden layers_{}_features count_{}".format(h,f),
                    exist_ok = True)
        with tf.Session() as sess:
            #summary_writer_train = tf.summary.FileWriter('./logs/kdd/VAE/training', graph=sess.graph)
            #summary_writer_valid = tf.summary.FileWriter('./logs/kdd/VAE/validation')

            sess.run(tf.global_variables_initializer())
            start_time = time.perf_counter()
            
            
            for c, lr in enumerate(lrs):
                for epoch in range(1, (epochs+1)):
                    for key, x_train, y_train in preprocess.get_data(train_paths):
                        x_train, x_valid, y_train, y_valid, = ms.train_test_split(x_train, 
                                                                                  y_train, 
                                                                                  test_size=0.1)
                        batch_indices = np.array_split(np.arange(x_train.shape[0]), 
                                                   batch_iterations)

                        for i in batch_indices:

                            _, train_loss = sess.run([net.train_op, net.regularized_loss], #net.summary_op
                                                      feed_dict={net.x_input: x_train[i,np.newaxis,:], 
                                                                 net.y_input_: y_train[i,np.newaxis,:], 
                                                                 net.keep_prob:1, net.lr:lr})
                            #summary_writer_train.add_summary(summary_str, epoch)
                            if(train_loss > 1e9):
                                print("Step {} | Training Loss: {:.6f}".format(epoch, train_loss))


                        valid_accuracy,valid_loss = sess.run([net.tf_accuracy, net.regularized_loss], #net.summary_op 
                                                              feed_dict={net.x_input: x_valid[:,np.newaxis,:], 
                                                                         net.y_input_: y_valid[:,np.newaxis,:], 
                                                                         net.keep_prob:1, net.lr:lr})
                        #summary_writer_valid.add_summary(summary_str, epoch)

                        
                    end_time = time.perf_counter() 
                    for key, x_test, y_test in preprocess.get_data(test_paths):
                        accuracy, pred_value, actual_value, y_pred = sess.run([net.tf_accuracy, 
                                                                               net.pred, 
                                                                               net.actual, net.y], 
                                                                              feed_dict={net.x_input: x_test[:,np.newaxis,:], 
                                                                                         net.y_input_: y_test[:,np.newaxis,:], 
                                                                                         net.keep_prob:1, net.lr:lr})

                        quality_score = me.matthews_corrcoef(actual_value, pred_value)
                        recall = me.recall_score(actual_value, pred_value)
                        prec = me.precision_score(actual_value, pred_value)
                        accuracy = me.roc_auc_score(actual_value, pred_value)
                        
                        print("Key {} | Training Loss: {:.6f} | Train Accuracy: {:.6f} | Test Accuracy: {:.6f}, quality_score: {}, recall: {}, prec: {}".format(key, train_loss, valid_accuracy, accuracy, quality_score, recall, prec))

                        if accuracy > Train.best_acc_global:
                                    Train.best_acc_global = accuracy
                                    Train.pred_value = pred_value
                                    Train.actual_value = actual_value

                                    Train.best_parameters = "Hidden Layers:{}, Features Count:{}".format(h, f)

                        curr_pred = pd.DataFrame({"Attack_prob":y_pred[:,-2], "Normal_prob":y_pred[:, -1], "Prediction":pred_value, "Actual":actual_value})
                        Train.predictions.update({"{}_{}_{}".format(key,f,h):
                                                  (curr_pred, 
                                                   Train.result(key, f, h,valid_accuracy, accuracy, quality_score, end_time - start_time))})

# %%
import itertools

df_results = []
past_scores = []

class Hyperparameters:
#    features_arr = [2, 4, 8, 16, 32, 64, 128, 256]
#    hidden_layers_arr = [2, 4, 6, 10]

    def start_training():

        global df_results
        global past_scores
        
        Train.predictions = {}
        Train.results = []
        
        features_arr = [1.5, 3, 4.5, 6] #[4, 8, 16, 32]
        hidden_layers_arr = [1, 3]

        epochs = [40]
        lrs = [1e-5] #[1e-2, 1e-2/2, 1e-2/4]

        for e, h, f in itertools.product(epochs, hidden_layers_arr, features_arr):
            print("Current Layer Attributes - epochs:{} hidden layers:{} features count:{}".format(e,h,f))
            n = network(2,h,f)
            n.build_layers()
            Train.train(e, n, h,f, lrs)
            
        dict1 = {}
        dict2 = []
        for k, (v1, v2) in Train.predictions.items():
            dict1.update({k: v1})
            dict2.append(v2)
            
        Train.predictions = dict1
        Train.results = dict2
        df_results = pd.DataFrame(Train.results)
        #temp = df_results.set_index(['no_of_features', 'hidden_layers'])

        if not os.path.isfile('dataset/scores/tf_lstm_mawih4.pkl'):
            past_scores = df_results
        else:
            past_scores = pd.read_pickle("dataset/scores/tf_lstm_mawih4.pkl")

        past_scores.append(df_results).to_pickle("dataset/scores/tf_lstm_mawih4.pkl")

# %%
Hyperparameters.start_training()
# Out:
# Current Layer Attributes - epochs:40 hidden layers:1 features count:1.5
# Key mawiitest | Training Loss: 0.708341 | Train Accuracy: 1.000000 | Test Accuracy: 0.999808, quality_score: 0.9997237141603467, recall: 1.0, prec: 0.9998308753889866
# Key mawiitest | Training Loss: 0.664439 | Train Accuracy: 1.000000 | Test Accuracy: 0.999808, quality_score: 0.9997237141603467, recall: 1.0, prec: 0.9998308753889866
# Key mawiitest | Training Loss: 0.702994 | Train Accuracy: 1.000000 | Test Accuracy: 0.999808, quality_score: 0.9997237141603467, recall: 1.0, prec: 0.9998308753889866
# Key mawiitest | Training Loss: 0.652384 | Train Accuracy: 1.000000 | Test Accuracy: 0.999808, quality_score: 0.9997237141603467, recall: 1.0, prec: 0.9998308753889866
# Key mawiitest | Training Loss: 0.587198 | Train Accuracy: 1.000000 | Test Accuracy: 0.999808, quality_score: 0.9997237141603467, recall: 1.0, prec: 0.9998308753889866
# Key mawiitest | Training Loss: 0.540644 | Train Accuracy: 1.000000 | Test Accuracy: 0.999808, quality_score: 0.9997237141603467, recall: 1.0, prec: 0.9998308753889866
# Key mawiitest | Training Loss: 0.542880 | Train Accuracy: 1.000000 | Test Accuracy: 0.999808, quality_score: 0.9997237141603467, recall: 1.0, prec: 0.9998308753889866
# Key mawiitest | Training Loss: 0.528246 | Train Accuracy: 1.000000 | Test Accuracy: 0.999808, quality_score: 0.9997237141603467, recall: 1.0, prec: 0.9998308753889866
# Key mawiitest | Training Loss: 0.522708 | Train Accuracy: 1.000000 | Test Accuracy: 0.999808, quality_score: 0.9997237141603467, recall: 1.0, prec: 0.9998308753889866
# Key mawiitest | Training Loss: 0.474999 | Train Accuracy: 1.000000 | Test Accuracy: 0.999808, quality_score: 0.9997237141603467, recall: 1.0, prec: 0.9998308753889866
# Key mawiitest | Training Loss: 0.513711 | Train Accuracy: 1.000000 | Test Accuracy: 0.999808, quality_score: 0.9997237141603467, recall: 1.0, prec: 0.9998308753889866
# Key mawiitest | Training Loss: 0.476554 | Train Accuracy: 1.000000 | Test Accuracy: 0.999808, quality_score: 0.9997237141603467, recall: 1.0, prec: 0.9998308753889866
# Key mawiitest | Training Loss: 0.425424 | Train Accuracy: 1.000000 | Test Accuracy: 0.999808, quality_score: 0.9997237141603467, recall: 1.0, prec: 0.9998308753889866
# Key mawiitest | Training Loss: 0.409893 | Train Accuracy: 1.000000 | Test Accuracy: 0.999808, quality_score: 0.9997237141603467, recall: 1.0, prec: 0.9998308753889866
# Key mawiitest | Training Loss: 0.436283 | Train Accuracy: 1.000000 | Test Accuracy: 0.999808, quality_score: 0.9997237141603467, recall: 1.0, prec: 0.9998308753889866
# Key mawiitest | Training Loss: 0.370591 | Train Accuracy: 1.000000 | Test Accuracy: 0.999808, quality_score: 0.9997237141603467, recall: 1.0, prec: 0.9998308753889866
# Key mawiitest | Training Loss: 0.359491 | Train Accuracy: 0.820312 | Test Accuracy: 0.650345, quality_score: 0.47937180823630293, recall: 1.0, prec: 0.764232897254253
# Key mawiitest | Training Loss: 0.384229 | Train Accuracy: 0.843750 | Test Accuracy: 0.647929, quality_score: 0.4751183142258663, recall: 1.0, prec: 0.7629901138328902
# Key mawiitest | Training Loss: 0.371427 | Train Accuracy: 0.835938 | Test Accuracy: 0.645821, quality_score: 0.4713850019133846, recall: 1.0, prec: 0.761908444169502
# Key mawiitest | Training Loss: 0.416033 | Train Accuracy: 0.968750 | Test Accuracy: 0.997891, quality_score: 0.99696179079628, recall: 1.0, prec: 0.9981427703113392
# Key mawiitest | Training Loss: 0.332334 | Train Accuracy: 0.968750 | Test Accuracy: 0.998620, quality_score: 0.9980111223479551, recall: 1.0, prec: 0.9987835783071465
# Key mawiitest | Training Loss: 0.350861 | Train Accuracy: 0.973958 | Test Accuracy: 0.998351, quality_score: 0.9976244982278338, recall: 1.0, prec: 0.9985473954462536
# Key mawiitest | Training Loss: 0.324948 | Train Accuracy: 0.958333 | Test Accuracy: 0.997814, quality_score: 0.9968513489600228, recall: 1.0, prec: 0.9980753646677472
# Key mawiitest | Training Loss: 0.327015 | Train Accuracy: 0.963542 | Test Accuracy: 0.997431, quality_score: 0.9962991799466087, recall: 1.0, prec: 0.9977384729629379
# Key mawiitest | Training Loss: 0.255680 | Train Accuracy: 0.966146 | Test Accuracy: 0.997086, quality_score: 0.9958022849142912, recall: 1.0, prec: 0.997435464822001
# Key mawiitest | Training Loss: 0.249742 | Train Accuracy: 0.973958 | Test Accuracy: 0.996242, quality_score: 0.9945878790223445, recall: 1.0, prec: 0.9966955524833935
# Key mawiitest | Training Loss: 0.241133 | Train Accuracy: 0.958333 | Test Accuracy: 0.995667, quality_score: 0.9937600581184404, recall: 1.0, prec: 0.9961916958748989
# Key mawiitest | Training Loss: 0.286938 | Train Accuracy: 0.885417 | Test Accuracy: 0.825537, quality_score: 0.7511478433371437, recall: 1.0, prec: 0.8666041220792167
# Key mawiitest | Training Loss: 0.329402 | Train Accuracy: 0.846354 | Test Accuracy: 0.647968, quality_score: 0.4751860188603424, recall: 1.0, prec: 0.7630098089829633
# Key mawiitest | Training Loss: 0.269683 | Train Accuracy: 0.828125 | Test Accuracy: 0.649080, quality_score: 0.47714678950033074, recall: 1.0, prec: 0.7635814109684586
# Key mawiitest | Training Loss: 0.206815 | Train Accuracy: 0.835938 | Test Accuracy: 0.648773, quality_score: 0.4766063998638775, recall: 1.0, prec: 0.7634236421395181
# Key mawiitest | Training Loss: 0.264243 | Train Accuracy: 0.846354 | Test Accuracy: 0.646298, quality_score: 0.4643456496346281, recall: 0.9965831049764877, prec: 0.7624100626326414
# Key mawiitest | Training Loss: 0.243101 | Train Accuracy: 0.815104 | Test Accuracy: 0.644956, quality_score: 0.461923191687995, recall: 0.9965831049764877, prec: 0.761720063093114
# Key mawiitest | Training Loss: 0.182761 | Train Accuracy: 0.830729 | Test Accuracy: 0.645284, quality_score: 0.4598799835015476, recall: 0.9953990324435874, prec: 0.7619775211063345
# Key mawiitest | Training Loss: 0.233497 | Train Accuracy: 0.841146 | Test Accuracy: 0.646299, quality_score: 0.46112745257650023, recall: 0.9951283872932102, prec: 0.7625207382828701
# Key mawiitest | Training Loss: 0.163881 | Train Accuracy: 0.861979 | Test Accuracy: 0.645124, quality_score: 0.45854869265875753, recall: 0.9949254034304272, prec: 0.7619306699829007
# Key mawiitest | Training Loss: 0.243054 | Train Accuracy: 0.838542 | Test Accuracy: 0.645162, quality_score: 0.4586184794576398, recall: 0.9949254034304272, prec: 0.7619504106536777
# Key mawiitest | Training Loss: 0.159465 | Train Accuracy: 0.807292 | Test Accuracy: 0.645137, quality_score: 0.4581299680392634, recall: 0.9947224195676444, prec: 0.7619528881287414
# Key mawiitest | Training Loss: 0.210983 | Train Accuracy: 0.841146 | Test Accuracy: 0.646220, quality_score: 0.45980564758807396, recall: 0.9945870969924557, prec: 0.7625210737906887
# Key mawiitest | Training Loss: 0.212702 | Train Accuracy: 0.820312 | Test Accuracy: 0.646143, quality_score: 0.4596662570360786, recall: 0.9945870969924557, prec: 0.7624815208652126
# Current Layer Attributes - epochs:40 hidden layers:1 features count:3
# Key mawiitest | Training Loss: 0.571930 | Train Accuracy: 0.752604 | Test Accuracy: 0.531417, quality_score: 0.17711480931648907, recall: 0.991745322913495, prec: 0.7076132084580476
# Key mawiitest | Training Loss: 0.512381 | Train Accuracy: 0.765625 | Test Accuracy: 0.531701, quality_score: 0.1792383335812736, recall: 0.9920836293514665, prec: 0.7077350066369011
# Key mawiitest | Training Loss: 0.694416 | Train Accuracy: 0.742188 | Test Accuracy: 0.532463, quality_score: 0.18709465665746594, recall: 0.9936060083223384, prec: 0.7080520732883318
# Key mawiitest | Training Loss: 0.454382 | Train Accuracy: 0.723958 | Test Accuracy: 0.532463, quality_score: 0.18709465665746594, recall: 0.9936060083223384, prec: 0.7080520732883318
# Key mawiitest | Training Loss: 0.216055 | Train Accuracy: 0.747396 | Test Accuracy: 0.532801, quality_score: 0.1907108772483247, recall: 0.9942826211982814, prec: 0.7081927710843373
# Key mawiitest | Training Loss: 0.426988 | Train Accuracy: 0.773438 | Test Accuracy: 0.535592, quality_score: 0.22402942587771643, recall: 0.9998646774248114, prec: 0.7093483739349574
# Key mawiitest | Training Loss: 0.386341 | Train Accuracy: 0.804688 | Test Accuracy: 0.535643, quality_score: 0.22470192555375015, recall: 0.9999661693562029, prec: 0.7093693001823942
# Key mawiitest | Training Loss: 0.612653 | Train Accuracy: 0.760417 | Test Accuracy: 0.535583, quality_score: 0.2246793195265601, recall: 1.0, prec: 0.7093422284082456
# Key mawiitest | Training Loss: 0.141671 | Train Accuracy: 0.796875 | Test Accuracy: 0.535199, quality_score: 0.22343867571514833, recall: 1.0, prec: 0.7091720448165831
# Key mawiitest | Training Loss: 0.135098 | Train Accuracy: 0.744792 | Test Accuracy: 0.534624, quality_score: 0.2215658132165284, recall: 1.0, prec: 0.7089169224865695
# Key mawiitest | Training Loss: 0.596455 | Train Accuracy: 0.768229 | Test Accuracy: 0.533052, quality_score: 0.21637101945061188, recall: 1.0, prec: 0.7082205237559
# Key mawiitest | Training Loss: 0.362568 | Train Accuracy: 0.809896 | Test Accuracy: 0.530828, quality_score: 0.20881992365500388, recall: 1.0, prec: 0.7072377078597918
# Key mawiitest | Training Loss: 0.314224 | Train Accuracy: 0.736979 | Test Accuracy: 0.530752, quality_score: 0.20855504576692493, recall: 1.0, prec: 0.7072038663061943
# Key mawiitest | Training Loss: 0.129045 | Train Accuracy: 0.781250 | Test Accuracy: 0.530138, quality_score: 0.206424709390018, recall: 1.0, prec: 0.7069332504245092
# Key mawiitest | Training Loss: 0.110835 | Train Accuracy: 0.736979 | Test Accuracy: 0.508819, quality_score: 0.1109292008165183, recall: 1.0, prec: 0.6976563053175671
# Key mawiitest | Training Loss: 0.215265 | Train Accuracy: 0.755208 | Test Accuracy: 0.500230, quality_score: 0.017869507499337023, recall: 1.0, prec: 0.693987274904327
# Key mawiitest | Training Loss: 0.102332 | Train Accuracy: 0.755208 | Test Accuracy: 0.500230, quality_score: 0.017869507499337023, recall: 1.0, prec: 0.693987274904327
# Key mawiitest | Training Loss: 0.316968 | Train Accuracy: 0.736979 | Test Accuracy: 0.500230, quality_score: 0.017869507499337023, recall: 1.0, prec: 0.693987274904327
# Key mawiitest | Training Loss: 0.318926 | Train Accuracy: 0.690104 | Test Accuracy: 0.500230, quality_score: 0.017869507499337023, recall: 1.0, prec: 0.693987274904327
# Key mawiitest | Training Loss: 0.080138 | Train Accuracy: 0.718750 | Test Accuracy: 0.500230, quality_score: 0.017869507499337023, recall: 1.0, prec: 0.693987274904327
# Key mawiitest | Training Loss: 0.309038 | Train Accuracy: 0.716146 | Test Accuracy: 0.500230, quality_score: 0.017869507499337023, recall: 1.0, prec: 0.693987274904327
# Key mawiitest | Training Loss: 0.083861 | Train Accuracy: 0.776042 | Test Accuracy: 0.508819, quality_score: 0.1109292008165183, recall: 1.0, prec: 0.6976563053175671
# Key mawiitest | Training Loss: 0.590370 | Train Accuracy: 0.757812 | Test Accuracy: 0.508857, quality_score: 0.11117140165177335, recall: 1.0, prec: 0.6976727719033232
# Key mawiitest | Training Loss: 0.296779 | Train Accuracy: 0.747396 | Test Accuracy: 0.509471, quality_score: 0.11497875128057695, recall: 1.0, prec: 0.6979363430298451
# Key mawiitest | Training Loss: 0.074516 | Train Accuracy: 0.729167 | Test Accuracy: 0.509471, quality_score: 0.11497875128057695, recall: 1.0, prec: 0.6979363430298451
# Key mawiitest | Training Loss: 0.289166 | Train Accuracy: 0.734375 | Test Accuracy: 0.509663, quality_score: 0.11614352930313547, recall: 1.0, prec: 0.6980187498524099
# Key mawiitest | Training Loss: 0.068312 | Train Accuracy: 0.763021 | Test Accuracy: 0.511541, quality_score: 0.12700751079337477, recall: 1.0, prec: 0.6988273677242423
# Key mawiitest | Training Loss: 0.068457 | Train Accuracy: 0.744792 | Test Accuracy: 0.512078, quality_score: 0.12994911252485875, recall: 1.0, prec: 0.6990587456248226
# Key mawiitest | Training Loss: 0.278561 | Train Accuracy: 0.729167 | Test Accuracy: 0.512538, quality_score: 0.1324199902046292, recall: 1.0, prec: 0.6992571915215746
# Key mawiitest | Training Loss: 0.061659 | Train Accuracy: 0.776042 | Test Accuracy: 0.513113, quality_score: 0.13544712631918085, recall: 1.0, prec: 0.6995054073881251
# Key mawiitest | Training Loss: 0.149896 | Train Accuracy: 0.736979 | Test Accuracy: 0.513152, quality_score: 0.13564660892080416, recall: 1.0, prec: 0.6995219613782658
# Key mawiitest | Training Loss: 0.272184 | Train Accuracy: 0.791667 | Test Accuracy: 0.513459, quality_score: 0.1372323669627821, recall: 1.0, prec: 0.6996544215110775
# Key mawiitest | Training Loss: 0.347147 | Train Accuracy: 0.713542 | Test Accuracy: 0.534854, quality_score: 0.22231668966965817, recall: 1.0, prec: 0.7090189493883425
# Key mawiitest | Training Loss: 0.262387 | Train Accuracy: 0.765625 | Test Accuracy: 0.534893, quality_score: 0.2224416102853292, recall: 1.0, prec: 0.7090359567271942
# Key mawiitest | Training Loss: 0.124683 | Train Accuracy: 0.794271 | Test Accuracy: 0.534931, quality_score: 0.22256646677448014, recall: 1.0, prec: 0.7090529648819804
# Key mawiitest | Training Loss: 0.138634 | Train Accuracy: 0.812500 | Test Accuracy: 0.535046, quality_score: 0.2229406525642478, recall: 1.0, prec: 0.7091039942425332
# Key mawiitest | Training Loss: 0.049324 | Train Accuracy: 0.768229 | Test Accuracy: 0.535084, quality_score: 0.22306525362726917, recall: 1.0, prec: 0.7091210056616447
# Key mawiitest | Training Loss: 0.335946 | Train Accuracy: 0.747396 | Test Accuracy: 0.535123, quality_score: 0.22318979110226533, recall: 1.0, prec: 0.7091380178969844
# Key mawiitest | Training Loss: 0.046158 | Train Accuracy: 0.739583 | Test Accuracy: 0.535123, quality_score: 0.22318979110226533, recall: 1.0, prec: 0.7091380178969844
# Key mawiitest | Training Loss: 0.044695 | Train Accuracy: 0.755208 | Test Accuracy: 0.535199, quality_score: 0.22343867571514833, recall: 1.0, prec: 0.7091720448165831
# Current Layer Attributes - epochs:40 hidden layers:1 features count:4.5
# Key mawiitest | Training Loss: 0.755559 | Train Accuracy: 0.221354 | Test Accuracy: 0.468364, quality_score: -0.18418252632629542, recall: 0.006360161033864474, prec: 0.17153284671532848
# Key mawiitest | Training Loss: 0.770230 | Train Accuracy: 0.213542 | Test Accuracy: 0.468407, quality_score: -0.18426070454152269, recall: 0.0062924997462701715, prec: 0.17032967032967034
# Key mawiitest | Training Loss: 0.700860 | Train Accuracy: 0.226562 | Test Accuracy: 0.468407, quality_score: -0.18426070454152269, recall: 0.0062924997462701715, prec: 0.17032967032967034
# Key mawiitest | Training Loss: 0.688345 | Train Accuracy: 0.200521 | Test Accuracy: 0.468522, quality_score: -0.1838358695104838, recall: 0.0062924997462701715, prec: 0.17079889807162535
# Key mawiitest | Training Loss: 0.728118 | Train Accuracy: 0.252604 | Test Accuracy: 0.468522, quality_score: -0.1838358695104838, recall: 0.0062924997462701715, prec: 0.17079889807162535
# Key mawiitest | Training Loss: 0.689546 | Train Accuracy: 0.242188 | Test Accuracy: 0.468637, quality_score: -0.18341026112511324, recall: 0.0062924997462701715, prec: 0.1712707182320442
# Key mawiitest | Training Loss: 0.701349 | Train Accuracy: 0.226562 | Test Accuracy: 0.468637, quality_score: -0.18341026112511324, recall: 0.0062924997462701715, prec: 0.1712707182320442
# Key mawiitest | Training Loss: 0.688361 | Train Accuracy: 0.239583 | Test Accuracy: 0.468637, quality_score: -0.18341026112511324, recall: 0.0062924997462701715, prec: 0.1712707182320442
# Key mawiitest | Training Loss: 0.653176 | Train Accuracy: 0.210938 | Test Accuracy: 0.468714, quality_score: -0.18312609048741563, recall: 0.0062924997462701715, prec: 0.17158671586715868
# Key mawiitest | Training Loss: 0.620210 | Train Accuracy: 0.244792 | Test Accuracy: 0.468714, quality_score: -0.18312609048741563, recall: 0.0062924997462701715, prec: 0.17158671586715868
# Key mawiitest | Training Loss: 0.650884 | Train Accuracy: 0.265625 | Test Accuracy: 0.468752, quality_score: -0.18298387518498405, recall: 0.0062924997462701715, prec: 0.17174515235457063
# Key mawiitest | Training Loss: 0.619632 | Train Accuracy: 0.257812 | Test Accuracy: 0.468752, quality_score: -0.18298387518498405, recall: 0.0062924997462701715, prec: 0.17174515235457063
# Key mawiitest | Training Loss: 0.609159 | Train Accuracy: 0.234375 | Test Accuracy: 0.468752, quality_score: -0.18298387518498405, recall: 0.0062924997462701715, prec: 0.17174515235457063
# Key mawiitest | Training Loss: 0.598982 | Train Accuracy: 0.231771 | Test Accuracy: 0.468735, quality_score: -0.1831653076240198, recall: 0.00625866910247302, prec: 0.1709796672828096
# Key mawiitest | Training Loss: 0.607681 | Train Accuracy: 0.218750 | Test Accuracy: 0.468812, quality_score: -0.1828807338718724, recall: 0.00625866910247302, prec: 0.1712962962962963
# Key mawiitest | Training Loss: 0.579731 | Train Accuracy: 0.247396 | Test Accuracy: 0.468812, quality_score: -0.1828807338718724, recall: 0.00625866910247302, prec: 0.1712962962962963
# Key mawiitest | Training Loss: 0.555824 | Train Accuracy: 0.255208 | Test Accuracy: 0.469080, quality_score: -0.18188197261962386, recall: 0.00625866910247302, prec: 0.1724137931034483
# Key mawiitest | Training Loss: 0.575883 | Train Accuracy: 0.270833 | Test Accuracy: 0.469131, quality_score: -0.1813367019664299, recall: 0.006360161033864474, prec: 0.17472118959107807
# Key mawiitest | Training Loss: 0.553695 | Train Accuracy: 0.247396 | Test Accuracy: 0.469361, quality_score: -0.1804761179387864, recall: 0.006360161033864474, prec: 0.17570093457943925
# Key mawiitest | Training Loss: 0.553186 | Train Accuracy: 0.200521 | Test Accuracy: 0.469395, quality_score: -0.18011293122909813, recall: 0.006427822321458778, prec: 0.17723880597014927
# Key mawiitest | Training Loss: 0.549406 | Train Accuracy: 0.463542 | Test Accuracy: 0.725240, quality_score: 0.42775142243075703, recall: 0.5178118339592003, prec: 0.9457488877904103
# Key mawiitest | Training Loss: 0.530548 | Train Accuracy: 0.963542 | Test Accuracy: 0.966334, quality_score: 0.9517166132164312, recall: 1.0, prec: 0.9711535302427966
# Key mawiitest | Training Loss: 0.533881 | Train Accuracy: 0.966146 | Test Accuracy: 0.966488, quality_score: 0.9519356602164327, recall: 1.0, prec: 0.9712811750402524
# Key mawiitest | Training Loss: 0.517130 | Train Accuracy: 0.971354 | Test Accuracy: 0.966488, quality_score: 0.9519356602164327, recall: 1.0, prec: 0.9712811750402524
# Key mawiitest | Training Loss: 0.518708 | Train Accuracy: 0.963542 | Test Accuracy: 0.966488, quality_score: 0.9519356602164327, recall: 1.0, prec: 0.9712811750402524
# Key mawiitest | Training Loss: 0.512721 | Train Accuracy: 0.966146 | Test Accuracy: 0.966488, quality_score: 0.9519356602164327, recall: 1.0, prec: 0.9712811750402524
# Key mawiitest | Training Loss: 0.490694 | Train Accuracy: 0.971354 | Test Accuracy: 0.966488, quality_score: 0.9519356602164327, recall: 1.0, prec: 0.9712811750402524
# Key mawiitest | Training Loss: 0.498093 | Train Accuracy: 0.976562 | Test Accuracy: 0.966181, quality_score: 0.9514975733751755, recall: 1.0, prec: 0.9710259189908347
# Key mawiitest | Training Loss: 0.485014 | Train Accuracy: 0.966146 | Test Accuracy: 0.965683, quality_score: 0.950785743116527, recall: 1.0, prec: 0.970611413935772
# Key mawiitest | Training Loss: 0.484775 | Train Accuracy: 0.973958 | Test Accuracy: 0.965567, quality_score: 0.9506214852423788, recall: 1.0, prec: 0.970515809173589
# Key mawiitest | Training Loss: 0.467280 | Train Accuracy: 0.953125 | Test Accuracy: 0.964954, quality_score: 0.9497455102280462, recall: 1.0, prec: 0.9700062350277294
# Key mawiitest | Training Loss: 0.470288 | Train Accuracy: 0.968750 | Test Accuracy: 0.964877, quality_score: 0.9496360212482104, recall: 1.0, prec: 0.9699425758818704
# Key mawiitest | Training Loss: 0.460207 | Train Accuracy: 0.950521 | Test Accuracy: 0.964647, quality_score: 0.9493075647845909, recall: 1.0, prec: 0.9697516485679604
# Key mawiitest | Training Loss: 0.443776 | Train Accuracy: 0.971354 | Test Accuracy: 0.964456, quality_score: 0.9490338630353786, recall: 1.0, prec: 0.969592599881913
# Key mawiitest | Training Loss: 0.433396 | Train Accuracy: 0.963542 | Test Accuracy: 0.964302, quality_score: 0.9488149094461819, recall: 1.0, prec: 0.9694653984913086
# Key mawiitest | Training Loss: 0.433230 | Train Accuracy: 0.966146 | Test Accuracy: 0.963995, quality_score: 0.9483770230191995, recall: 1.0, prec: 0.9692110958095613
# Key mawiitest | Training Loss: 0.404786 | Train Accuracy: 0.953125 | Test Accuracy: 0.934279, quality_score: 0.9060654688438456, recall: 1.0, prec: 0.9451923384389089
# Key mawiitest | Training Loss: 0.424207 | Train Accuracy: 0.947917 | Test Accuracy: 0.933282, quality_score: 0.9046489089513052, recall: 1.0, prec: 0.9444071695581329
# Key mawiitest | Training Loss: 0.412718 | Train Accuracy: 0.947917 | Test Accuracy: 0.932400, quality_score: 0.9033959113288609, recall: 1.0, prec: 0.9437136836728178
# Key mawiitest | Training Loss: 0.412122 | Train Accuracy: 0.916667 | Test Accuracy: 0.866296, quality_score: 0.8094993654728266, recall: 1.0, prec: 0.8944804212310113
# Current Layer Attributes - epochs:40 hidden layers:1 features count:6
# c:\users\anusha\appdata\local\programs\python\python36\lib\site-packages\sklearn\metrics\classification.py:538: RuntimeWarning: invalid value encountered in double_scalars
#   mcc = cov_ytyp / np.sqrt(cov_ytyt * cov_ypyp)
# Key mawiitest | Training Loss: 0.438222 | Train Accuracy: 0.697917 | Test Accuracy: 0.500000, quality_score: 0.0, recall: 1.0, prec: 0.6938895279231907
# Key mawiitest | Training Loss: 0.400874 | Train Accuracy: 0.726562 | Test Accuracy: 0.500000, quality_score: 0.0, recall: 1.0, prec: 0.6938895279231907
# Key mawiitest | Training Loss: 0.408854 | Train Accuracy: 0.734375 | Test Accuracy: 0.500000, quality_score: 0.0, recall: 1.0, prec: 0.6938895279231907
# Key mawiitest | Training Loss: 0.383838 | Train Accuracy: 0.726562 | Test Accuracy: 0.500000, quality_score: 0.0, recall: 1.0, prec: 0.6938895279231907
# Key mawiitest | Training Loss: 0.393713 | Train Accuracy: 0.763021 | Test Accuracy: 0.500000, quality_score: 0.0, recall: 1.0, prec: 0.6938895279231907
# Key mawiitest | Training Loss: 0.367513 | Train Accuracy: 0.747396 | Test Accuracy: 0.500000, quality_score: 0.0, recall: 1.0, prec: 0.6938895279231907
# Key mawiitest | Training Loss: 0.377480 | Train Accuracy: 0.731771 | Test Accuracy: 0.500000, quality_score: 0.0, recall: 1.0, prec: 0.6938895279231907
# Key mawiitest | Training Loss: 0.350943 | Train Accuracy: 0.966146 | Test Accuracy: 0.969172, quality_score: 0.9557701601985883, recall: 1.0, prec: 0.9735204031222211
# Key mawiitest | Training Loss: 0.342017 | Train Accuracy: 0.986979 | Test Accuracy: 0.978489, quality_score: 0.9690997502567745, recall: 1.0, prec: 0.9813745019920319
# Key mawiitest | Training Loss: 0.333260 | Train Accuracy: 0.976562 | Test Accuracy: 0.978489, quality_score: 0.9690997502567745, recall: 1.0, prec: 0.9813745019920319
# Key mawiitest | Training Loss: 0.325763 | Train Accuracy: 0.979167 | Test Accuracy: 0.978489, quality_score: 0.9690997502567745, recall: 1.0, prec: 0.9813745019920319
# Key mawiitest | Training Loss: 0.335610 | Train Accuracy: 0.984375 | Test Accuracy: 0.978489, quality_score: 0.9690997502567745, recall: 1.0, prec: 0.9813745019920319
# Key mawiitest | Training Loss: 0.350202 | Train Accuracy: 0.979167 | Test Accuracy: 0.978489, quality_score: 0.9690997502567745, recall: 1.0, prec: 0.9813745019920319
# Key mawiitest | Training Loss: 0.324749 | Train Accuracy: 0.979167 | Test Accuracy: 0.969248, quality_score: 0.9558797505788286, recall: 1.0, prec: 0.9735845327887751
# Key mawiitest | Training Loss: 0.310702 | Train Accuracy: 0.976562 | Test Accuracy: 0.966948, quality_score: 0.9525928443464203, recall: 1.0, prec: 0.971664310837908
# Key mawiitest | Training Loss: 0.278789 | Train Accuracy: 0.960938 | Test Accuracy: 0.965721, quality_score: 0.9508404966262781, recall: 1.0, prec: 0.9706432863757265
# Key mawiitest | Training Loss: 0.257346 | Train Accuracy: 0.963542 | Test Accuracy: 0.965146, quality_score: 0.9500192403373935, recall: 1.0, prec: 0.9701654194564789
# Key mawiitest | Training Loss: 0.320296 | Train Accuracy: 0.963542 | Test Accuracy: 0.964839, quality_score: 0.949581277413731, recall: 1.0, prec: 0.969910749442184
# Key mawiitest | Training Loss: 0.300597 | Train Accuracy: 0.955729 | Test Accuracy: 0.964494, quality_score: 0.9490886025164963, recall: 1.0, prec: 0.9696244054453009
# Key mawiitest | Training Loss: 0.258816 | Train Accuracy: 0.950521 | Test Accuracy: 0.935046, quality_score: 0.907155225730433, recall: 1.0, prec: 0.9457972034684671
# Key mawiitest | Training Loss: 0.254439 | Train Accuracy: 0.947917 | Test Accuracy: 0.934164, quality_score: 0.9059020125466702, recall: 1.0, prec: 0.9451016754060622
# Key mawiitest | Training Loss: 0.222593 | Train Accuracy: 0.921875 | Test Accuracy: 0.866641, quality_score: 0.809990902473857, recall: 1.0, prec: 0.8947240972243242
# Key mawiitest | Training Loss: 0.263274 | Train Accuracy: 0.893229 | Test Accuracy: 0.858397, quality_score: 0.7982396726340063, recall: 1.0, prec: 0.888939011187297
# Key mawiitest | Training Loss: 0.211820 | Train Accuracy: 0.901042 | Test Accuracy: 0.856748, quality_score: 0.7958870060454415, recall: 1.0, prec: 0.887790959603544
# Key mawiitest | Training Loss: 0.192408 | Train Accuracy: 0.916667 | Test Accuracy: 0.855138, quality_score: 0.793588204144648, recall: 1.0, prec: 0.8866724660287368
# Key mawiitest | Training Loss: 0.151596 | Train Accuracy: 0.908854 | Test Accuracy: 0.852837, quality_score: 0.7903026882876095, recall: 1.0, prec: 0.8850794981585173
# Key mawiitest | Training Loss: 0.266893 | Train Accuracy: 0.903646 | Test Accuracy: 0.849808, quality_score: 0.7859739114457142, recall: 1.0, prec: 0.8829907993786593
# Key mawiitest | Training Loss: 0.090574 | Train Accuracy: 0.755208 | Test Accuracy: 0.500000, quality_score: 0.0, recall: 1.0, prec: 0.6938895279231907
# Key mawiitest | Training Loss: 0.075115 | Train Accuracy: 0.747396 | Test Accuracy: 0.500000, quality_score: 0.0, recall: 1.0, prec: 0.6938895279231907
# Key mawiitest | Training Loss: 0.161372 | Train Accuracy: 0.765625 | Test Accuracy: 0.500000, quality_score: 0.0, recall: 1.0, prec: 0.6938895279231907
# Key mawiitest | Training Loss: 0.070391 | Train Accuracy: 0.726562 | Test Accuracy: 0.500000, quality_score: 0.0, recall: 1.0, prec: 0.6938895279231907
# Key mawiitest | Training Loss: 0.172968 | Train Accuracy: 0.739583 | Test Accuracy: 0.500000, quality_score: 0.0, recall: 1.0, prec: 0.6938895279231907
# Key mawiitest | Training Loss: 0.175896 | Train Accuracy: 0.708333 | Test Accuracy: 0.500000, quality_score: 0.0, recall: 1.0, prec: 0.6938895279231907
# Key mawiitest | Training Loss: 0.258997 | Train Accuracy: 0.734375 | Test Accuracy: 0.500000, quality_score: 0.0, recall: 1.0, prec: 0.6938895279231907
# Key mawiitest | Training Loss: 0.055975 | Train Accuracy: 0.752604 | Test Accuracy: 0.500000, quality_score: 0.0, recall: 1.0, prec: 0.6938895279231907
# Key mawiitest | Training Loss: 0.155804 | Train Accuracy: 0.713542 | Test Accuracy: 0.500000, quality_score: 0.0, recall: 1.0, prec: 0.6938895279231907
# Key mawiitest | Training Loss: 0.149274 | Train Accuracy: 0.755208 | Test Accuracy: 0.500000, quality_score: 0.0, recall: 1.0, prec: 0.6938895279231907
# Key mawiitest | Training Loss: 0.055856 | Train Accuracy: 0.729167 | Test Accuracy: 0.500000, quality_score: 0.0, recall: 1.0, prec: 0.6938895279231907
# Key mawiitest | Training Loss: 0.236166 | Train Accuracy: 0.734375 | Test Accuracy: 0.500000, quality_score: 0.0, recall: 1.0, prec: 0.6938895279231907
# Key mawiitest | Training Loss: 0.050800 | Train Accuracy: 0.747396 | Test Accuracy: 0.500000, quality_score: 0.0, recall: 1.0, prec: 0.6938895279231907
# Current Layer Attributes - epochs:40 hidden layers:3 features count:1.5
# Key mawiitest | Training Loss: 0.492100 | Train Accuracy: 0.731771 | Test Accuracy: 0.503374, quality_score: 0.0685009742982925, recall: 1.0, prec: 0.6953259156453624
# Key mawiitest | Training Loss: 0.485744 | Train Accuracy: 0.710938 | Test Accuracy: 0.500000, quality_score: 0.0, recall: 1.0, prec: 0.6938895279231907
# Key mawiitest | Training Loss: 0.481625 | Train Accuracy: 0.773438 | Test Accuracy: 0.500000, quality_score: 0.0, recall: 1.0, prec: 0.6938895279231907
# Key mawiitest | Training Loss: 0.474618 | Train Accuracy: 0.747396 | Test Accuracy: 0.500000, quality_score: 0.0, recall: 1.0, prec: 0.6938895279231907
# Key mawiitest | Training Loss: 0.462113 | Train Accuracy: 0.731771 | Test Accuracy: 0.500000, quality_score: 0.0, recall: 1.0, prec: 0.6938895279231907
# Key mawiitest | Training Loss: 0.454135 | Train Accuracy: 0.723958 | Test Accuracy: 0.500000, quality_score: 0.0, recall: 1.0, prec: 0.6938895279231907
# Key mawiitest | Training Loss: 0.455293 | Train Accuracy: 0.718750 | Test Accuracy: 0.500000, quality_score: 0.0, recall: 1.0, prec: 0.6938895279231907
# Key mawiitest | Training Loss: 0.426927 | Train Accuracy: 0.744792 | Test Accuracy: 0.500000, quality_score: 0.0, recall: 1.0, prec: 0.6938895279231907
# Key mawiitest | Training Loss: 0.427980 | Train Accuracy: 0.747396 | Test Accuracy: 0.500000, quality_score: 0.0, recall: 1.0, prec: 0.6938895279231907
# Key mawiitest | Training Loss: 0.419606 | Train Accuracy: 0.757812 | Test Accuracy: 0.500000, quality_score: 0.0, recall: 1.0, prec: 0.6938895279231907
# Key mawiitest | Training Loss: 0.426825 | Train Accuracy: 0.729167 | Test Accuracy: 0.500000, quality_score: 0.0, recall: 1.0, prec: 0.6938895279231907
# Key mawiitest | Training Loss: 0.440625 | Train Accuracy: 0.729167 | Test Accuracy: 0.500000, quality_score: 0.0, recall: 1.0, prec: 0.6938895279231907
# Key mawiitest | Training Loss: 0.363512 | Train Accuracy: 0.726562 | Test Accuracy: 0.500000, quality_score: 0.0, recall: 1.0, prec: 0.6938895279231907
# Key mawiitest | Training Loss: 0.350465 | Train Accuracy: 0.755208 | Test Accuracy: 0.500000, quality_score: 0.0, recall: 1.0, prec: 0.6938895279231907
# Key mawiitest | Training Loss: 0.366608 | Train Accuracy: 0.700521 | Test Accuracy: 0.500000, quality_score: 0.0, recall: 1.0, prec: 0.6938895279231907
# Key mawiitest | Training Loss: 0.321058 | Train Accuracy: 0.812500 | Test Accuracy: 0.500000, quality_score: 0.0, recall: 1.0, prec: 0.6938895279231907
# Key mawiitest | Training Loss: 0.381265 | Train Accuracy: 0.736979 | Test Accuracy: 0.500000, quality_score: 0.0, recall: 1.0, prec: 0.6938895279231907
# Key mawiitest | Training Loss: 0.292104 | Train Accuracy: 0.700521 | Test Accuracy: 0.500000, quality_score: 0.0, recall: 1.0, prec: 0.6938895279231907
# Key mawiitest | Training Loss: 0.277727 | Train Accuracy: 0.731771 | Test Accuracy: 0.500000, quality_score: 0.0, recall: 1.0, prec: 0.6938895279231907
# Key mawiitest | Training Loss: 0.312060 | Train Accuracy: 0.742188 | Test Accuracy: 0.500000, quality_score: 0.0, recall: 1.0, prec: 0.6938895279231907
# Key mawiitest | Training Loss: 0.302057 | Train Accuracy: 0.723958 | Test Accuracy: 0.500000, quality_score: 0.0, recall: 1.0, prec: 0.6938895279231907
# Key mawiitest | Training Loss: 0.292284 | Train Accuracy: 0.736979 | Test Accuracy: 0.500000, quality_score: 0.0, recall: 1.0, prec: 0.6938895279231907
# Key mawiitest | Training Loss: 0.283093 | Train Accuracy: 0.713542 | Test Accuracy: 0.500000, quality_score: 0.0, recall: 1.0, prec: 0.6938895279231907
# Key mawiitest | Training Loss: 0.339100 | Train Accuracy: 0.736979 | Test Accuracy: 0.500000, quality_score: 0.0, recall: 1.0, prec: 0.6938895279231907
# Key mawiitest | Training Loss: 0.198836 | Train Accuracy: 0.744792 | Test Accuracy: 0.500000, quality_score: 0.0, recall: 1.0, prec: 0.6938895279231907
# Key mawiitest | Training Loss: 0.188542 | Train Accuracy: 0.736979 | Test Accuracy: 0.500000, quality_score: 0.0, recall: 1.0, prec: 0.6938895279231907
# Key mawiitest | Training Loss: 0.253192 | Train Accuracy: 0.736979 | Test Accuracy: 0.500000, quality_score: 0.0, recall: 1.0, prec: 0.6938895279231907
# Key mawiitest | Training Loss: 0.168447 | Train Accuracy: 0.752604 | Test Accuracy: 0.500000, quality_score: 0.0, recall: 1.0, prec: 0.6938895279231907
# Key mawiitest | Training Loss: 0.158683 | Train Accuracy: 0.736979 | Test Accuracy: 0.500000, quality_score: 0.0, recall: 1.0, prec: 0.6938895279231907
# Key mawiitest | Training Loss: 0.238268 | Train Accuracy: 0.765625 | Test Accuracy: 0.500000, quality_score: 0.0, recall: 1.0, prec: 0.6938895279231907
# Key mawiitest | Training Loss: 0.147006 | Train Accuracy: 0.773438 | Test Accuracy: 0.500000, quality_score: 0.0, recall: 1.0, prec: 0.6938895279231907
# Key mawiitest | Training Loss: 0.231530 | Train Accuracy: 0.697917 | Test Accuracy: 0.500000, quality_score: 0.0, recall: 1.0, prec: 0.6938895279231907
# Key mawiitest | Training Loss: 0.324456 | Train Accuracy: 0.705729 | Test Accuracy: 0.500000, quality_score: 0.0, recall: 1.0, prec: 0.6938895279231907
# Key mawiitest | Training Loss: 0.223609 | Train Accuracy: 0.684896 | Test Accuracy: 0.500000, quality_score: 0.0, recall: 1.0, prec: 0.6938895279231907
# Key mawiitest | Training Loss: 0.223612 | Train Accuracy: 0.760417 | Test Accuracy: 0.500000, quality_score: 0.0, recall: 1.0, prec: 0.6938895279231907
# Key mawiitest | Training Loss: 0.333035 | Train Accuracy: 0.752604 | Test Accuracy: 0.500000, quality_score: 0.0, recall: 1.0, prec: 0.6938895279231907
# Key mawiitest | Training Loss: 0.218687 | Train Accuracy: 0.703125 | Test Accuracy: 0.500000, quality_score: 0.0, recall: 1.0, prec: 0.6938895279231907
# Key mawiitest | Training Loss: 0.220642 | Train Accuracy: 0.726562 | Test Accuracy: 0.500000, quality_score: 0.0, recall: 1.0, prec: 0.6938895279231907
# Key mawiitest | Training Loss: 0.219387 | Train Accuracy: 0.755208 | Test Accuracy: 0.500000, quality_score: 0.0, recall: 1.0, prec: 0.6938895279231907
# Key mawiitest | Training Loss: 0.224115 | Train Accuracy: 0.692708 | Test Accuracy: 0.500000, quality_score: 0.0, recall: 1.0, prec: 0.6938895279231907
# Current Layer Attributes - epochs:40 hidden layers:3 features count:3
# Key mawiitest | Training Loss: 0.486943 | Train Accuracy: 0.718750 | Test Accuracy: 0.500000, quality_score: 0.0, recall: 1.0, prec: 0.6938895279231907
# Key mawiitest | Training Loss: 0.478691 | Train Accuracy: 0.713542 | Test Accuracy: 0.500000, quality_score: 0.0, recall: 1.0, prec: 0.6938895279231907
# Key mawiitest | Training Loss: 0.485976 | Train Accuracy: 0.750000 | Test Accuracy: 0.500000, quality_score: 0.0, recall: 1.0, prec: 0.6938895279231907
# Key mawiitest | Training Loss: 0.479120 | Train Accuracy: 0.729167 | Test Accuracy: 0.500000, quality_score: 0.0, recall: 1.0, prec: 0.6938895279231907
# Key mawiitest | Training Loss: 0.453215 | Train Accuracy: 0.716146 | Test Accuracy: 0.500000, quality_score: 0.0, recall: 1.0, prec: 0.6938895279231907
# Key mawiitest | Training Loss: 0.443375 | Train Accuracy: 0.760417 | Test Accuracy: 0.500000, quality_score: 0.0, recall: 1.0, prec: 0.6938895279231907
# Key mawiitest | Training Loss: 0.433023 | Train Accuracy: 0.734375 | Test Accuracy: 0.500000, quality_score: 0.0, recall: 1.0, prec: 0.6938895279231907
# Key mawiitest | Training Loss: 0.456810 | Train Accuracy: 0.742188 | Test Accuracy: 0.500000, quality_score: 0.0, recall: 1.0, prec: 0.6938895279231907
# Key mawiitest | Training Loss: 0.409128 | Train Accuracy: 0.726562 | Test Accuracy: 0.500000, quality_score: 0.0, recall: 1.0, prec: 0.6938895279231907
# Key mawiitest | Training Loss: 0.359988 | Train Accuracy: 0.697917 | Test Accuracy: 0.500000, quality_score: 0.0, recall: 1.0, prec: 0.6938895279231907
# Key mawiitest | Training Loss: 0.387148 | Train Accuracy: 0.731771 | Test Accuracy: 0.500000, quality_score: 0.0, recall: 1.0, prec: 0.6938895279231907
# Key mawiitest | Training Loss: 0.374634 | Train Accuracy: 0.718750 | Test Accuracy: 0.500000, quality_score: 0.0, recall: 1.0, prec: 0.6938895279231907
# Key mawiitest | Training Loss: 0.310443 | Train Accuracy: 0.747396 | Test Accuracy: 0.500000, quality_score: 0.0, recall: 1.0, prec: 0.6938895279231907
# Key mawiitest | Training Loss: 0.404954 | Train Accuracy: 0.726562 | Test Accuracy: 0.500000, quality_score: 0.0, recall: 1.0, prec: 0.6938895279231907
# Key mawiitest | Training Loss: 0.276295 | Train Accuracy: 0.708333 | Test Accuracy: 0.500000, quality_score: 0.0, recall: 1.0, prec: 0.6938895279231907
# Key mawiitest | Training Loss: 0.259607 | Train Accuracy: 0.731771 | Test Accuracy: 0.500000, quality_score: 0.0, recall: 1.0, prec: 0.6938895279231907
# Key mawiitest | Training Loss: 0.243198 | Train Accuracy: 0.736979 | Test Accuracy: 0.500000, quality_score: 0.0, recall: 1.0, prec: 0.6938895279231907
# Key mawiitest | Training Loss: 0.227977 | Train Accuracy: 0.736979 | Test Accuracy: 0.500000, quality_score: 0.0, recall: 1.0, prec: 0.6938895279231907
# Key mawiitest | Training Loss: 0.213174 | Train Accuracy: 0.723958 | Test Accuracy: 0.500000, quality_score: 0.0, recall: 1.0, prec: 0.6938895279231907
# Key mawiitest | Training Loss: 0.281809 | Train Accuracy: 0.757812 | Test Accuracy: 0.500000, quality_score: 0.0, recall: 1.0, prec: 0.6938895279231907
# Key mawiitest | Training Loss: 0.187118 | Train Accuracy: 0.755208 | Test Accuracy: 0.500000, quality_score: 0.0, recall: 1.0, prec: 0.6938895279231907
# Key mawiitest | Training Loss: 0.175254 | Train Accuracy: 0.734375 | Test Accuracy: 0.500000, quality_score: 0.0, recall: 1.0, prec: 0.6938895279231907
# Key mawiitest | Training Loss: 0.164778 | Train Accuracy: 0.726562 | Test Accuracy: 0.500000, quality_score: 0.0, recall: 1.0, prec: 0.6938895279231907
# Key mawiitest | Training Loss: 0.155101 | Train Accuracy: 0.739583 | Test Accuracy: 0.500000, quality_score: 0.0, recall: 1.0, prec: 0.6938895279231907
# Key mawiitest | Training Loss: 0.240511 | Train Accuracy: 0.744792 | Test Accuracy: 0.500000, quality_score: 0.0, recall: 1.0, prec: 0.6938895279231907
# Key mawiitest | Training Loss: 0.137921 | Train Accuracy: 0.736979 | Test Accuracy: 0.500000, quality_score: 0.0, recall: 1.0, prec: 0.6938895279231907
# Key mawiitest | Training Loss: 0.342842 | Train Accuracy: 0.742188 | Test Accuracy: 0.500000, quality_score: 0.0, recall: 1.0, prec: 0.6938895279231907
# Key mawiitest | Training Loss: 0.341899 | Train Accuracy: 0.752604 | Test Accuracy: 0.500000, quality_score: 0.0, recall: 1.0, prec: 0.6938895279231907
# Key mawiitest | Training Loss: 0.231547 | Train Accuracy: 0.708333 | Test Accuracy: 0.500000, quality_score: 0.0, recall: 1.0, prec: 0.6938895279231907
# Key mawiitest | Training Loss: 0.228099 | Train Accuracy: 0.710938 | Test Accuracy: 0.500000, quality_score: 0.0, recall: 1.0, prec: 0.6938895279231907
# Key mawiitest | Training Loss: 0.110115 | Train Accuracy: 0.747396 | Test Accuracy: 0.500000, quality_score: 0.0, recall: 1.0, prec: 0.6938895279231907
# Key mawiitest | Training Loss: 0.226133 | Train Accuracy: 0.729167 | Test Accuracy: 0.500000, quality_score: 0.0, recall: 1.0, prec: 0.6938895279231907
# Key mawiitest | Training Loss: 0.226009 | Train Accuracy: 0.703125 | Test Accuracy: 0.500000, quality_score: 0.0, recall: 1.0, prec: 0.6938895279231907
# Key mawiitest | Training Loss: 0.344699 | Train Accuracy: 0.713542 | Test Accuracy: 0.500000, quality_score: 0.0, recall: 1.0, prec: 0.6938895279231907
# Key mawiitest | Training Loss: 0.094217 | Train Accuracy: 0.747396 | Test Accuracy: 0.500000, quality_score: 0.0, recall: 1.0, prec: 0.6938895279231907
# Key mawiitest | Training Loss: 0.347688 | Train Accuracy: 0.739583 | Test Accuracy: 0.500000, quality_score: 0.0, recall: 1.0, prec: 0.6938895279231907
# Key mawiitest | Training Loss: 0.355031 | Train Accuracy: 0.776042 | Test Accuracy: 0.500000, quality_score: 0.0, recall: 1.0, prec: 0.6938895279231907
# Key mawiitest | Training Loss: 0.225337 | Train Accuracy: 0.763021 | Test Accuracy: 0.500000, quality_score: 0.0, recall: 1.0, prec: 0.6938895279231907
# Key mawiitest | Training Loss: 0.222030 | Train Accuracy: 0.718750 | Test Accuracy: 0.500000, quality_score: 0.0, recall: 1.0, prec: 0.6938895279231907
# Key mawiitest | Training Loss: 0.083950 | Train Accuracy: 0.750000 | Test Accuracy: 0.500000, quality_score: 0.0, recall: 1.0, prec: 0.6938895279231907
# Current Layer Attributes - epochs:40 hidden layers:3 features count:4.5
# Key mawiitest | Training Loss: 0.490127 | Train Accuracy: 0.736979 | Test Accuracy: 0.499983, quality_score: -0.003218098421646356, recall: 0.9999661693562029, prec: 0.6938823418939857
# Key mawiitest | Training Loss: 0.481178 | Train Accuracy: 0.734375 | Test Accuracy: 0.500000, quality_score: 0.0, recall: 1.0, prec: 0.6938895279231907
# Key mawiitest | Training Loss: 0.466267 | Train Accuracy: 0.760417 | Test Accuracy: 0.500000, quality_score: 0.0, recall: 1.0, prec: 0.6938895279231907
# Key mawiitest | Training Loss: 0.458473 | Train Accuracy: 0.731771 | Test Accuracy: 0.500000, quality_score: 0.0, recall: 1.0, prec: 0.6938895279231907
# Key mawiitest | Training Loss: 0.446421 | Train Accuracy: 0.690104 | Test Accuracy: 0.500000, quality_score: 0.0, recall: 1.0, prec: 0.6938895279231907
# Key mawiitest | Training Loss: 0.447359 | Train Accuracy: 0.716146 | Test Accuracy: 0.500000, quality_score: 0.0, recall: 1.0, prec: 0.6938895279231907
# Key mawiitest | Training Loss: 0.422431 | Train Accuracy: 0.700521 | Test Accuracy: 0.500000, quality_score: 0.0, recall: 1.0, prec: 0.6938895279231907
# Key mawiitest | Training Loss: 0.402826 | Train Accuracy: 0.752604 | Test Accuracy: 0.500000, quality_score: 0.0, recall: 1.0, prec: 0.6938895279231907
# Key mawiitest | Training Loss: 0.411810 | Train Accuracy: 0.731771 | Test Accuracy: 0.500000, quality_score: 0.0, recall: 1.0, prec: 0.6938895279231907
# Key mawiitest | Training Loss: 0.401157 | Train Accuracy: 0.731771 | Test Accuracy: 0.500000, quality_score: 0.0, recall: 1.0, prec: 0.6938895279231907
# Key mawiitest | Training Loss: 0.351102 | Train Accuracy: 0.736979 | Test Accuracy: 0.500000, quality_score: 0.0, recall: 1.0, prec: 0.6938895279231907
# Key mawiitest | Training Loss: 0.337814 | Train Accuracy: 0.731771 | Test Accuracy: 0.500000, quality_score: 0.0, recall: 1.0, prec: 0.6938895279231907
# Key mawiitest | Training Loss: 0.425894 | Train Accuracy: 0.739583 | Test Accuracy: 0.500000, quality_score: 0.0, recall: 1.0, prec: 0.6938895279231907
# Key mawiitest | Training Loss: 0.302808 | Train Accuracy: 0.718750 | Test Accuracy: 0.500000, quality_score: 0.0, recall: 1.0, prec: 0.6938895279231907
# Key mawiitest | Training Loss: 0.340877 | Train Accuracy: 0.723958 | Test Accuracy: 0.500000, quality_score: 0.0, recall: 1.0, prec: 0.6938895279231907
# Key mawiitest | Training Loss: 0.269975 | Train Accuracy: 0.739583 | Test Accuracy: 0.500000, quality_score: 0.0, recall: 1.0, prec: 0.6938895279231907
# Key mawiitest | Training Loss: 0.255243 | Train Accuracy: 0.721354 | Test Accuracy: 0.500000, quality_score: 0.0, recall: 1.0, prec: 0.6938895279231907
# Key mawiitest | Training Loss: 0.241529 | Train Accuracy: 0.736979 | Test Accuracy: 0.500000, quality_score: 0.0, recall: 1.0, prec: 0.6938895279231907
# Key mawiitest | Training Loss: 0.296097 | Train Accuracy: 0.742188 | Test Accuracy: 0.500000, quality_score: 0.0, recall: 1.0, prec: 0.6938895279231907
# Key mawiitest | Training Loss: 0.215996 | Train Accuracy: 0.750000 | Test Accuracy: 0.500000, quality_score: 0.0, recall: 1.0, prec: 0.6938895279231907
# Key mawiitest | Training Loss: 0.196434 | Train Accuracy: 0.763021 | Test Accuracy: 0.500000, quality_score: 0.0, recall: 1.0, prec: 0.6938895279231907
# Key mawiitest | Training Loss: 0.272052 | Train Accuracy: 0.752604 | Test Accuracy: 0.500000, quality_score: 0.0, recall: 1.0, prec: 0.6938895279231907
# Key mawiitest | Training Loss: 0.261542 | Train Accuracy: 0.750000 | Test Accuracy: 0.500000, quality_score: 0.0, recall: 1.0, prec: 0.6938895279231907
# Key mawiitest | Training Loss: 0.256272 | Train Accuracy: 0.721354 | Test Accuracy: 0.500000, quality_score: 0.0, recall: 1.0, prec: 0.6938895279231907
# Key mawiitest | Training Loss: 0.244915 | Train Accuracy: 0.744792 | Test Accuracy: 0.500000, quality_score: 0.0, recall: 1.0, prec: 0.6938895279231907
# Key mawiitest | Training Loss: 0.149846 | Train Accuracy: 0.718750 | Test Accuracy: 0.500000, quality_score: 0.0, recall: 1.0, prec: 0.6938895279231907
# Key mawiitest | Training Loss: 0.151073 | Train Accuracy: 0.734375 | Test Accuracy: 0.500000, quality_score: 0.0, recall: 1.0, prec: 0.6938895279231907
# Key mawiitest | Training Loss: 0.135930 | Train Accuracy: 0.757812 | Test Accuracy: 0.500000, quality_score: 0.0, recall: 1.0, prec: 0.6938895279231907
# Key mawiitest | Training Loss: 0.232365 | Train Accuracy: 0.726562 | Test Accuracy: 0.500000, quality_score: 0.0, recall: 1.0, prec: 0.6938895279231907
# Key mawiitest | Training Loss: 0.123512 | Train Accuracy: 0.760417 | Test Accuracy: 0.500000, quality_score: 0.0, recall: 1.0, prec: 0.6938895279231907
# Key mawiitest | Training Loss: 0.334812 | Train Accuracy: 0.744792 | Test Accuracy: 0.500000, quality_score: 0.0, recall: 1.0, prec: 0.6938895279231907
# Key mawiitest | Training Loss: 0.113888 | Train Accuracy: 0.705729 | Test Accuracy: 0.500000, quality_score: 0.0, recall: 1.0, prec: 0.6938895279231907
# Key mawiitest | Training Loss: 0.109349 | Train Accuracy: 0.736979 | Test Accuracy: 0.500000, quality_score: 0.0, recall: 1.0, prec: 0.6938895279231907
# Key mawiitest | Training Loss: 0.105163 | Train Accuracy: 0.718750 | Test Accuracy: 0.500000, quality_score: 0.0, recall: 1.0, prec: 0.6938895279231907
# Key mawiitest | Training Loss: 0.101686 | Train Accuracy: 0.729167 | Test Accuracy: 0.500000, quality_score: 0.0, recall: 1.0, prec: 0.6938895279231907
# Key mawiitest | Training Loss: 0.097750 | Train Accuracy: 0.705729 | Test Accuracy: 0.500000, quality_score: 0.0, recall: 1.0, prec: 0.6938895279231907
# Key mawiitest | Training Loss: 0.213170 | Train Accuracy: 0.778646 | Test Accuracy: 0.500000, quality_score: 0.0, recall: 1.0, prec: 0.6938895279231907
# Key mawiitest | Training Loss: 0.092155 | Train Accuracy: 0.763021 | Test Accuracy: 0.500000, quality_score: 0.0, recall: 1.0, prec: 0.6938895279231907
# Key mawiitest | Training Loss: 0.089582 | Train Accuracy: 0.755208 | Test Accuracy: 0.500000, quality_score: 0.0, recall: 1.0, prec: 0.6938895279231907
# Key mawiitest | Training Loss: 0.086676 | Train Accuracy: 0.734375 | Test Accuracy: 0.500000, quality_score: 0.0, recall: 1.0, prec: 0.6938895279231907
# Current Layer Attributes - epochs:40 hidden layers:3 features count:6
# Key mawiitest | Training Loss: 0.487460 | Train Accuracy: 0.726562 | Test Accuracy: 0.500000, quality_score: 0.0, recall: 1.0, prec: 0.6938895279231907
# Key mawiitest | Training Loss: 0.475731 | Train Accuracy: 0.716146 | Test Accuracy: 0.500000, quality_score: 0.0, recall: 1.0, prec: 0.6938895279231907
# Key mawiitest | Training Loss: 0.471312 | Train Accuracy: 0.770833 | Test Accuracy: 0.500000, quality_score: 0.0, recall: 1.0, prec: 0.6938895279231907
# Key mawiitest | Training Loss: 0.462806 | Train Accuracy: 0.731771 | Test Accuracy: 0.500000, quality_score: 0.0, recall: 1.0, prec: 0.6938895279231907
# Key mawiitest | Training Loss: 0.454149 | Train Accuracy: 0.752604 | Test Accuracy: 0.500000, quality_score: 0.0, recall: 1.0, prec: 0.6938895279231907
# Key mawiitest | Training Loss: 0.444707 | Train Accuracy: 0.750000 | Test Accuracy: 0.500000, quality_score: 0.0, recall: 1.0, prec: 0.6938895279231907
# Key mawiitest | Training Loss: 0.435016 | Train Accuracy: 0.726562 | Test Accuracy: 0.500000, quality_score: 0.0, recall: 1.0, prec: 0.6938895279231907
# Key mawiitest | Training Loss: 0.424593 | Train Accuracy: 0.692708 | Test Accuracy: 0.500000, quality_score: 0.0, recall: 1.0, prec: 0.6938895279231907
# Key mawiitest | Training Loss: 0.429796 | Train Accuracy: 0.734375 | Test Accuracy: 0.500000, quality_score: 0.0, recall: 1.0, prec: 0.6938895279231907
# Key mawiitest | Training Loss: 0.383699 | Train Accuracy: 0.750000 | Test Accuracy: 0.500000, quality_score: 0.0, recall: 1.0, prec: 0.6938895279231907
# Key mawiitest | Training Loss: 0.368927 | Train Accuracy: 0.750000 | Test Accuracy: 0.500000, quality_score: 0.0, recall: 1.0, prec: 0.6938895279231907
# Key mawiitest | Training Loss: 0.350264 | Train Accuracy: 0.781250 | Test Accuracy: 0.500000, quality_score: 0.0, recall: 1.0, prec: 0.6938895279231907
# Key mawiitest | Training Loss: 0.385072 | Train Accuracy: 0.757812 | Test Accuracy: 0.500000, quality_score: 0.0, recall: 1.0, prec: 0.6938895279231907
# Key mawiitest | Training Loss: 0.318538 | Train Accuracy: 0.723958 | Test Accuracy: 0.500000, quality_score: 0.0, recall: 1.0, prec: 0.6938895279231907
# Key mawiitest | Training Loss: 0.368791 | Train Accuracy: 0.723958 | Test Accuracy: 0.500000, quality_score: 0.0, recall: 1.0, prec: 0.6938895279231907
# Key mawiitest | Training Loss: 0.322758 | Train Accuracy: 0.692708 | Test Accuracy: 0.500000, quality_score: 0.0, recall: 1.0, prec: 0.6938895279231907
# Key mawiitest | Training Loss: 0.269835 | Train Accuracy: 0.721354 | Test Accuracy: 0.500000, quality_score: 0.0, recall: 1.0, prec: 0.6938895279231907
# Key mawiitest | Training Loss: 0.254273 | Train Accuracy: 0.734375 | Test Accuracy: 0.500000, quality_score: 0.0, recall: 1.0, prec: 0.6938895279231907
# Key mawiitest | Training Loss: 0.336179 | Train Accuracy: 0.755208 | Test Accuracy: 0.500000, quality_score: 0.0, recall: 1.0, prec: 0.6938895279231907
# Key mawiitest | Training Loss: 0.228914 | Train Accuracy: 0.747396 | Test Accuracy: 0.500000, quality_score: 0.0, recall: 1.0, prec: 0.6938895279231907
# Key mawiitest | Training Loss: 0.271970 | Train Accuracy: 0.750000 | Test Accuracy: 0.500000, quality_score: 0.0, recall: 1.0, prec: 0.6938895279231907
# Key mawiitest | Training Loss: 0.206738 | Train Accuracy: 0.750000 | Test Accuracy: 0.500000, quality_score: 0.0, recall: 1.0, prec: 0.6938895279231907
# Key mawiitest | Training Loss: 0.257897 | Train Accuracy: 0.726562 | Test Accuracy: 0.500000, quality_score: 0.0, recall: 1.0, prec: 0.6938895279231907
# Key mawiitest | Training Loss: 0.185687 | Train Accuracy: 0.763021 | Test Accuracy: 0.500000, quality_score: 0.0, recall: 1.0, prec: 0.6938895279231907
# Key mawiitest | Training Loss: 0.178301 | Train Accuracy: 0.723958 | Test Accuracy: 0.500000, quality_score: 0.0, recall: 1.0, prec: 0.6938895279231907
# Key mawiitest | Training Loss: 0.241537 | Train Accuracy: 0.783854 | Test Accuracy: 0.500000, quality_score: 0.0, recall: 1.0, prec: 0.6938895279231907
# Key mawiitest | Training Loss: 0.162911 | Train Accuracy: 0.705729 | Test Accuracy: 0.500000, quality_score: 0.0, recall: 1.0, prec: 0.6938895279231907
# Key mawiitest | Training Loss: 0.156022 | Train Accuracy: 0.731771 | Test Accuracy: 0.500000, quality_score: 0.0, recall: 1.0, prec: 0.6938895279231907
# Key mawiitest | Training Loss: 0.149772 | Train Accuracy: 0.736979 | Test Accuracy: 0.500000, quality_score: 0.0, recall: 1.0, prec: 0.6938895279231907
# Key mawiitest | Training Loss: 0.312639 | Train Accuracy: 0.739583 | Test Accuracy: 0.500000, quality_score: 0.0, recall: 1.0, prec: 0.6938895279231907
# Key mawiitest | Training Loss: 0.401060 | Train Accuracy: 0.721354 | Test Accuracy: 0.500000, quality_score: 0.0, recall: 1.0, prec: 0.6938895279231907
# Key mawiitest | Training Loss: 0.224909 | Train Accuracy: 0.744792 | Test Accuracy: 0.500000, quality_score: 0.0, recall: 1.0, prec: 0.6938895279231907
# Key mawiitest | Training Loss: 0.315467 | Train Accuracy: 0.742188 | Test Accuracy: 0.500000, quality_score: 0.0, recall: 1.0, prec: 0.6938895279231907
# Key mawiitest | Training Loss: 0.219869 | Train Accuracy: 0.776042 | Test Accuracy: 0.500000, quality_score: 0.0, recall: 1.0, prec: 0.6938895279231907
# Key mawiitest | Training Loss: 0.218669 | Train Accuracy: 0.750000 | Test Accuracy: 0.500000, quality_score: 0.0, recall: 1.0, prec: 0.6938895279231907
# Key mawiitest | Training Loss: 0.217300 | Train Accuracy: 0.708333 | Test Accuracy: 0.500000, quality_score: 0.0, recall: 1.0, prec: 0.6938895279231907
# Key mawiitest | Training Loss: 0.321346 | Train Accuracy: 0.700521 | Test Accuracy: 0.500000, quality_score: 0.0, recall: 1.0, prec: 0.6938895279231907
# Key mawiitest | Training Loss: 0.106672 | Train Accuracy: 0.687500 | Test Accuracy: 0.500000, quality_score: 0.0, recall: 1.0, prec: 0.6938895279231907
# Key mawiitest | Training Loss: 0.103675 | Train Accuracy: 0.734375 | Test Accuracy: 0.500000, quality_score: 0.0, recall: 1.0, prec: 0.6938895279231907
# Key mawiitest | Training Loss: 0.101081 | Train Accuracy: 0.752604 | Test Accuracy: 0.500000, quality_score: 0.0, recall: 1.0, prec: 0.6938895279231907

# %%
pd.Panel(Train.predictions).to_pickle("dataset/tf_lstm_mawih4.pkl")
df_results.to_pickle("dataset/tf_lstm_scores_mawih4.pkl")

# %%
import numpy as np
import matplotlib.pyplot as plt
import itertools

def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    np.set_printoptions(precision=4)

    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        #print("Normalized confusion matrix")
    else:
        #print('Confusion matrix, without normalization')
        pass
    
    #print(cm)

    label = [["\n True Positive", "\n False Negative \n Type II Error"],
             ["\n False Positive \n Type I Error", "\n True Negative"]
            ]
    
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        
        plt.text(j, i, "{} {}".format(cm[i, j].round(4), label[i][j]),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')

def plot(actual_value, pred_value):
    from sklearn.metrics import confusion_matrix

    cm_2labels = confusion_matrix(y_pred = pred_value, y_true = actual_value)
    plt.figure(figsize=[6,6])
    plot_confusion_matrix(cm_2labels, ['Normal', 'Attack'], normalize = False)

# %%
past_scores = pd.read_pickle("dataset/scores/tf_lstm_mawih4.pkl")

# %%
past_scores.sort_values(by='quality_score', ascending = False)
# Out:
#          key  no_of_features  hidden_layers  train_score  test_score  \
# 2  mawiitest             4.5              1     0.916667    0.866296
# 0  mawiitest             1.5              1     0.820312    0.646143
# 1  mawiitest             3.0              1     0.755208    0.535199
# 1  mawiitest             3.0              1     0.736979    0.510475
# 1  mawiitest             3.0              1     0.736979    0.510475
# 0  mawiitest             1.5              1     0.752604    0.500000
# 5  mawiitest             3.0              3     0.729167    0.500000
# 6  mawiitest             4.5              3     0.734375    0.500000
# 5  mawiitest             3.0              3     0.750000    0.500000
# 4  mawiitest             1.5              3     0.692708    0.500000
# 3  mawiitest             6.0              1     0.747396    0.500000
# 7  mawiitest             6.0              3     0.742188    0.500000
# 6  mawiitest             4.5              3     0.713542    0.500000
# 4  mawiitest             1.5              3     0.721354    0.500000
# 3  mawiitest             6.0              1     0.700521    0.500000
# 2  mawiitest             4.5              1     0.742188    0.500000
# 0  mawiitest             1.5              1     0.752604    0.500000
# 7  mawiitest             6.0              3     0.742188    0.500000
# 6  mawiitest             4.5              3     0.713542    0.500000
# 5  mawiitest             3.0              3     0.729167    0.500000
# 4  mawiitest             1.5              3     0.721354    0.500000
# 3  mawiitest             6.0              1     0.700521    0.500000
# 2  mawiitest             4.5              1     0.742188    0.500000
# 7  mawiitest             6.0              3     0.752604    0.500000
#
#    quality_score  time_taken
# 2       0.809499   43.033756
# 0       0.459666   37.430219
# 1       0.223439   41.726588
# 1       0.094544  177.134700
# 1       0.094544  177.134700
# 0       0.000000  124.654747
# 5       0.000000  250.763411
# 6       0.000000   85.027343
# 5       0.000000   56.901701
# 4       0.000000   64.577971
# 3       0.000000   38.926369
# 7       0.000000  224.041596
# 6       0.000000  250.745226
# 4       0.000000  246.715467
# 3       0.000000  193.382353
# 2       0.000000  172.991566
# 0       0.000000  124.654747
# 7       0.000000  224.041596
# 6       0.000000  250.745226
# 5       0.000000  250.763411
# 4       0.000000  246.715467
# 3       0.000000  193.382353
# 2       0.000000  172.991566
# 7       0.000000   59.659590

# %%
psg = past_scores.sort_values(by='quality_score', ascending=False).groupby(by=['no_of_features', 'hidden_layers'])
psg.first().sort_values(by='quality_score', ascending=False)
# Out:
#                                     key  train_score  test_score  \
# no_of_features hidden_layers
# 4.5            1              mawiitest     0.916667    0.866296
# 1.5            1              mawiitest     0.820312    0.646143
# 3.0            1              mawiitest     0.755208    0.535199
# 1.5            3              mawiitest     0.692708    0.500000
# 3.0            3              mawiitest     0.729167    0.500000
# 4.5            3              mawiitest     0.734375    0.500000
# 6.0            1              mawiitest     0.747396    0.500000
#                3              mawiitest     0.742188    0.500000
#
#                               quality_score  time_taken
# no_of_features hidden_layers
# 4.5            1                   0.809499   43.033756
# 1.5            1                   0.459666   37.430219
# 3.0            1                   0.223439   41.726588
# 1.5            3                   0.000000   64.577971
# 3.0            3                   0.000000  250.763411
# 4.5            3                   0.000000   85.027343
# 6.0            1                   0.000000   38.926369
#                3                   0.000000  224.041596

# %%
Train.predictions = pd.read_pickle("dataset/tf_lstm_mawih4.pkl")

# %%
Train.predictions
# Out:
# <class 'pandas.core.panel.Panel'>
# Dimensions: 8 (items) x 42599 (major_axis) x 4 (minor_axis)
# Items axis: mawiitest_1.5_1 to mawiitest_6_3
# Major_axis axis: 0 to 42598
# Minor_axis axis: Actual to Prediction

# %%
df = Train.predictions['mawiitest_6_3'].dropna()

# %%
from sklearn import metrics as me
def get_score(y_true, y_pred):
    f1 = me.f1_score(y_true, y_pred)
    pre = me.precision_score(y_true, y_pred)
    rec = me.recall_score(y_true, y_pred)
    acc = me.accuracy_score(y_true, y_pred)
    return {"F1 Score":f1, "Precision":pre, "Recall":rec, "Accuracy":acc}

# %%
from sklearn import metrics as me

scores = get_score(df.loc[:,'Actual'].values.astype(int),
                df.loc[:,'Prediction'].values.astype(int))
scores.update({"Scenario":"Train/Test4"})
score_df = pd.DataFrame(scores, index=[0])

score_df
# Out:
#    Accuracy  F1 Score  Precision  Recall     Scenario
# 0   0.69389  0.819285    0.69389     1.0  Train/Test4

# %%
df.loc[:,'Prediction'].values.astype(int)
# Out:
# array([1, 1, 1, ..., 1, 1, 1])

# %%
from sklearn import metrics as me
me.f1_score(df.loc[:,'Actual'].values.astype(int),
            df.loc[:,'Prediction'].values.astype(int) )
# Out:
# 0.8192854569139943

# %%
me.matthews_corrcoef(df.loc[:,'Actual'].values.astype(int),
            df.loc[:,'Prediction'].values.astype(int) )
# Out:
# c:\users\anusha\appdata\local\programs\python\python36\lib\site-packages\sklearn\metrics\classification.py:538: RuntimeWarning: invalid value encountered in double_scalars
#   mcc = cov_ytyp / np.sqrt(cov_ytyt * cov_ypyp)
# 0.0

# %%
df.groupby(by="Actual").Actual.count()
# Out:
# Actual
# 0.0    13040
# 1.0    29559
# Name: Actual, dtype: int64

# %%
plot(actual_value = df.loc[:,'Actual'].values.astype(int),
     pred_value = df.loc[:,'Prediction'].values.astype(int))
